# %% [markdown]
# # XGBoost 2

# %%
import seaborn as sns

import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %%
# loading and exploring the datas
import warnings


warnings.filterwarnings("ignore")

diamonds = sns.load_dataset("diamonds")

diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
diamonds.describe(exclude=np.number)
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
# building XGBoost DMatrix
from sklearn.model_selection import train_test_split

# Extract feature and target arrays
X, y = diamonds.drop('price', axis=1), diamonds[['price']]

# %%
# Extract text features
cats = X.select_dtypes(exclude=np.number).columns.tolist()

# Convert to Pandas category
for col in cats:
   X[col] = X[col].astype('category')

# %%
X.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
# Split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
import xgboost as xgb

# Create regression matrices
dtrain_reg = xgb.DMatrix(X_train, y_train, enable_categorical=True)
dtest_reg = xgb.DMatrix(X_test, y_test, enable_categorical=True)

# %%
# Define hyperparameters
params = {"objective": "reg:squarederror", "tree_method": "gpu_hist"}

# %%
# Define hyperparameters
params = {"objective": "reg:squarederror", "tree_method": "gpu_hist"}

n = 100
model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
)

# %%
from sklearn.metrics import mean_squared_error

preds = model.predict(dtest_reg)

# %%
rmse = mean_squared_error(y_test, preds, squared=False)

print(f"RMSE of the base model: {rmse:.3f}")
# Out:
# RMSE of the base model: 555.607

# %%
# using validation sets during training
params = {"objective": "reg:squarederror", "tree_method": "gpu_hist"}
n = 100

# %%
evals = [(dtrain_reg, "train"), (dtest_reg, "validation")]

# %%
evals = [(dtrain_reg, "train"), (dtest_reg, "validation")]

model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
   evals=evals,
)
# Out:
# [0]	train-rmse:2874.29379	validation-rmse:2817.38773
# [1]	train-rmse:2092.07711	validation-rmse:2054.73630
# [2]	train-rmse:1549.52687	validation-rmse:1526.30592
# [3]	train-rmse:1184.46798	validation-rmse:1174.90119
# [4]	train-rmse:941.09127	validation-rmse:943.28272
# [5]	train-rmse:784.58014	validation-rmse:796.09651
# [6]	train-rmse:685.75110	validation-rmse:705.22245
# [7]	train-rmse:624.67281	validation-rmse:653.32563
# [8]	train-rmse:584.19599	validation-rmse:620.30404
# [9]	train-rmse:558.77667	validation-rmse:599.24504
# [10]	train-rmse:543.85303	validation-rmse:586.99790
# [11]	train-rmse:531.92694	validation-rmse:578.68120
# [12]	train-rmse:523.08456	validation-rmse:571.73527
# [13]	train-rmse:515.67753	validation-rmse:567.19913
# [14]	train-rmse:510.77594	validation-rmse:564.66402
# [15]	train-rmse:506.68519	validation-rmse:563.21547
# [16]	train-rmse:502.96796	validation-rmse:561.80880
# [17]	train-rmse:498.90184	validation-rmse:560.36561
# [18]	train-rmse:492.74859	validation-rmse:558.46274
# [19]	train-rmse:490.30278	validation-rmse:556.87216
# [20]	train-rmse:487.42071	validation-rmse:556.44229
# [21]	train-rmse:484.74496	validation-rmse:556.55429
# [22]	train-rmse:480.95735	validation-rmse:557.84139
# [23]	train-rmse:478.48520	validation-rmse:557.89540
# [24]	train-rmse:475.23956	validation-rmse:557.37962
# [25]	train-rmse:471.61791	validation-rmse:556.87508
# [26]	train-rmse:469.65231	validation-rmse:556.70128
# [27]	train-rmse:466.45165	validation-rmse:555.73740
# [28]	train-rmse:464.66200	validation-rmse:555.11206
# [29]	train-rmse:463.36324	validation-rmse:555.09142
# [30]	train-rmse:460.86396	validation-rmse:554.68339
# [31]	train-rmse:459.68274	validation-rmse:554.79977
# [32]	train-rmse:457.48581	validation-rmse:554.57599
# [33]	train-rmse:455.07939	validation-rmse:555.65575
# [34]	train-rmse:454.03028	validation-rmse:555.26394
# [35]	train-rmse:452.35989	validation-rmse:554.62246
# [36]	train-rmse:449.38579	validation-rmse:553.35840
# [37]	train-rmse:448.64842	validation-rmse:553.45248
# [38]	train-rmse:448.47633	validation-rmse:553.35233
# [39]	train-rmse:445.58979	validation-rmse:553.05158
# [40]	train-rmse:444.03762	validation-rmse:552.62130
# [41]	train-rmse:442.01167	validation-rmse:552.97558
# [42]	train-rmse:441.35357	validation-rmse:553.23244
# [43]	train-rmse:440.74163	validation-rmse:553.14153
# [44]	train-rmse:440.60815	validation-rmse:553.05782
# [45]	train-rmse:439.48758	validation-rmse:553.30981
# [46]	train-rmse:438.70697	validation-rmse:553.22313
# [47]	train-rmse:435.38239	validation-rmse:553.74845
# [48]	train-rmse:434.17988	validation-rmse:553.24786
# [49]	train-rmse:432.53983	validation-rmse:553.43480
# [50]	train-rmse:430.07110	validation-rmse:553.50718
# [51]	train-rmse:429.02843	validation-rmse:553.68181
# [52]	train-rmse:428.82789	validation-rmse:553.55179
# [53]	train-rmse:426.65097	validation-rmse:554.33720
# [54]	train-rmse:425.35817	validation-rmse:555.00412
# [55]	train-rmse:424.43950	validation-rmse:555.04530
# [56]	train-rmse:423.98886	validation-rmse:555.23862
# [57]	train-rmse:423.37385	validation-rmse:555.01524
# [58]	train-rmse:422.89152	validation-rmse:554.73559
# [59]	train-rmse:420.17877	validation-rmse:555.28689
# [60]	train-rmse:418.57995	validation-rmse:555.44368
# [61]	train-rmse:416.15098	validation-rmse:556.22395
# [62]	train-rmse:415.20122	validation-rmse:556.03493
# [63]	train-rmse:413.94128	validation-rmse:555.89869
# [64]	train-rmse:412.14760	validation-rmse:555.56320
# [65]	train-rmse:412.07284	validation-rmse:555.51809
# [66]	train-rmse:411.12288	validation-rmse:556.53856
# [67]	train-rmse:409.86233	validation-rmse:556.02134
# [68]	train-rmse:408.98845	validation-rmse:555.64995
# [69]	train-rmse:407.60369	validation-rmse:555.40507
# [70]	train-rmse:406.77489	validation-rmse:555.06703
# [71]	train-rmse:405.55576	validation-rmse:554.85987
# [72]	train-rmse:404.01644	validation-rmse:554.78435
# [73]	train-rmse:402.82464	validation-rmse:554.70160
# [74]	train-rmse:401.31075	validation-rmse:554.40804
# [75]	train-rmse:399.88578	validation-rmse:554.56453
# [76]	train-rmse:399.46555	validation-rmse:554.83544
# [77]	train-rmse:398.97065	validation-rmse:554.83387
# [78]	train-rmse:398.50360	validation-rmse:554.66181
# [79]	train-rmse:396.24144	validation-rmse:555.31061
# [80]	train-rmse:394.18070	validation-rmse:555.00800
# [81]	train-rmse:392.71336	validation-rmse:555.25449
# [82]	train-rmse:392.14361	validation-rmse:555.18259
# [83]	train-rmse:390.73064	validation-rmse:555.24386
# [84]	train-rmse:390.32572	validation-rmse:555.02768
# [85]	train-rmse:388.65251	validation-rmse:555.33841
# [86]	train-rmse:387.44200	validation-rmse:555.24404
# [87]	train-rmse:386.96057	validation-rmse:555.09808
# [88]	train-rmse:385.78554	validation-rmse:554.95239
# [89]	train-rmse:384.05170	validation-rmse:555.95636
# [90]	train-rmse:382.65353	validation-rmse:555.74725
# [91]	train-rmse:381.97534	validation-rmse:555.69323
# [92]	train-rmse:380.47646	validation-rmse:555.26134
# [93]	train-rmse:379.11827	validation-rmse:554.93934
# [94]	train-rmse:377.82598	validation-rmse:555.07593
# [95]	train-rmse:376.66849	validation-rmse:555.53397
# [96]	train-rmse:374.97521	validation-rmse:555.60914
# [97]	train-rmse:374.61227	validation-rmse:555.61898
# [98]	train-rmse:373.84881	validation-rmse:555.65889
# [99]	train-rmse:373.74308	validation-rmse:555.60692

# %%
params = {"objective": "reg:squarederror", "tree_method": "gpu_hist"}
n = 100

evals = [(dtest_reg, "validation"), (dtrain_reg, "train")]


model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
   evals=evals,
   verbose_eval=10 # Every ten rounds
)
# Out:
# [0]	validation-rmse:2817.38773	train-rmse:2874.29379
# [10]	validation-rmse:586.99790	train-rmse:543.85303
# [20]	validation-rmse:556.44229	train-rmse:487.42071
# [30]	validation-rmse:554.68339	train-rmse:460.86396
# [40]	validation-rmse:552.62130	train-rmse:444.03762
# [50]	validation-rmse:553.50718	train-rmse:430.07110
# [60]	validation-rmse:555.44368	train-rmse:418.57995
# [70]	validation-rmse:555.06703	train-rmse:406.77489
# [80]	validation-rmse:555.00800	train-rmse:394.18070
# [90]	validation-rmse:555.74725	train-rmse:382.65353
# [99]	validation-rmse:555.60692	train-rmse:373.74308

# %%
# XGBoost early stopping
params = {"objective": "reg:squarederror", "tree_method": "gpu_hist"}
n = 5000

evals = [(dtest_reg, "validation"), (dtrain_reg, "train")]


model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
   evals=evals,
   verbose_eval=500 #initial it was 250
)
# Out:
# [0]	validation-rmse:2817.38773	train-rmse:2874.29379
# [500]	validation-rmse:563.29248	train-rmse:197.72375
# [1000]	validation-rmse:572.18689	train-rmse:121.69016
# [1500]	validation-rmse:576.42698	train-rmse:84.17960
# [2000]	validation-rmse:578.58142	train-rmse:60.88001
# [2500]	validation-rmse:579.96944	train-rmse:46.47975
# [3000]	validation-rmse:580.78514	train-rmse:36.59124
# [3500]	validation-rmse:581.36774	train-rmse:29.47363
# [4000]	validation-rmse:581.86083	train-rmse:23.90580
# [4500]	validation-rmse:582.07031	train-rmse:19.97500
# [4999]	validation-rmse:582.23127	train-rmse:17.15835

# %%
n = 10000


model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
   evals=evals,
   verbose_eval=50,
   # Activate early stopping
   early_stopping_rounds=50
)
# Out:
# [0]	validation-rmse:2817.38773	train-rmse:2874.29379
# [50]	validation-rmse:553.50718	train-rmse:430.07110
# [100]	validation-rmse:555.39120	train-rmse:372.49371
# [150]	validation-rmse:557.80361	train-rmse:333.62595
# [200]	validation-rmse:559.48104	train-rmse:300.06795
# [250]	validation-rmse:561.30944	train-rmse:276.85755
# [300]	validation-rmse:561.43599	train-rmse:257.34345
# [350]	validation-rmse:561.82074	train-rmse:239.54154
# [400]	validation-rmse:563.09188	train-rmse:223.46175
# [450]	validation-rmse:563.07923	train-rmse:209.80627
# [500]	validation-rmse:563.29248	train-rmse:197.72375
# [550]	validation-rmse:565.24722	train-rmse:187.28444
# [600]	validation-rmse:566.42436	train-rmse:176.54386
# [650]	validation-rmse:567.17392	train-rmse:166.61162
# [700]	validation-rmse:568.01290	train-rmse:157.61657
# [750]	validation-rmse:568.62872	train-rmse:150.03843
# [800]	validation-rmse:569.21259	train-rmse:143.23111
# [850]	validation-rmse:569.80695	train-rmse:137.52825
# [900]	validation-rmse:570.23810	train-rmse:132.00300
# [950]	validation-rmse:571.27079	train-rmse:126.60925
# [1000]	validation-rmse:572.18689	train-rmse:121.69016
# [1050]	validation-rmse:572.26591	train-rmse:117.23333
# [1100]	validation-rmse:572.51476	train-rmse:112.65144
# [1150]	validation-rmse:572.86124	train-rmse:107.01818
# [1200]	validation-rmse:573.65554	train-rmse:103.21039
# [1250]	validation-rmse:574.18885	train-rmse:99.34243
# [1300]	validation-rmse:574.34282	train-rmse:95.59081
# [1350]	validation-rmse:574.68198	train-rmse:92.43305
# [1400]	validation-rmse:575.37809	train-rmse:88.92989
# [1450]	validation-rmse:575.86492	train-rmse:86.44249
# [1500]	validation-rmse:576.42698	train-rmse:84.17960
# [1550]	validation-rmse:576.94837	train-rmse:81.83121
# [1600]	validation-rmse:577.11270	train-rmse:78.92259
# [1650]	validation-rmse:577.95292	train-rmse:76.14858
# [1700]	validation-rmse:577.94317	train-rmse:73.73023
# [1750]	validation-rmse:578.10716	train-rmse:71.14960
# [1800]	validation-rmse:578.15425	train-rmse:69.15264
# [1850]	validation-rmse:578.24762	train-rmse:66.98569
# [1900]	validation-rmse:578.35025	train-rmse:65.24721
# [1950]	validation-rmse:578.46037	train-rmse:63.03072
# [2000]	validation-rmse:578.58142	train-rmse:60.88001
# [2050]	validation-rmse:578.77936	train-rmse:59.04889
# [2100]	validation-rmse:578.81325	train-rmse:57.64124
# [2150]	validation-rmse:579.06211	train-rmse:56.08847
# [2200]	validation-rmse:579.20091	train-rmse:54.21948
# [2250]	validation-rmse:579.16086	train-rmse:52.80762
# [2300]	validation-rmse:579.49855	train-rmse:51.32255
# [2350]	validation-rmse:579.51217	train-rmse:50.03363
# [2400]	validation-rmse:579.68487	train-rmse:48.98758
# [2450]	validation-rmse:579.85323	train-rmse:47.67437
# [2500]	validation-rmse:579.96944	train-rmse:46.47975
# [2550]	validation-rmse:580.04628	train-rmse:45.39903
# [2600]	validation-rmse:580.28155	train-rmse:44.27769
# [2650]	validation-rmse:580.37023	train-rmse:43.10057
# [2700]	validation-rmse:580.51064	train-rmse:42.20159
# [2750]	validation-rmse:580.51823	train-rmse:41.25980
# [2800]	validation-rmse:580.56224	train-rmse:40.30842
# [2850]	validation-rmse:580.62121	train-rmse:39.31618
# [2900]	validation-rmse:580.67217	train-rmse:38.31379
# [2950]	validation-rmse:580.77269	train-rmse:37.42036
# [3000]	validation-rmse:580.78514	train-rmse:36.59124
# [3050]	validation-rmse:580.86804	train-rmse:35.90396
# [3100]	validation-rmse:580.98818	train-rmse:35.12247
# [3150]	validation-rmse:580.98348	train-rmse:34.28401
# [3200]	validation-rmse:581.05380	train-rmse:33.52172
# [3250]	validation-rmse:581.21700	train-rmse:32.91052
# [3300]	validation-rmse:581.25792	train-rmse:32.13526
# [3350]	validation-rmse:581.24192	train-rmse:31.45731
# [3400]	validation-rmse:581.23104	train-rmse:30.76098
# [3450]	validation-rmse:581.29383	train-rmse:30.08798
# [3500]	validation-rmse:581.36774	train-rmse:29.47363
# [3550]	validation-rmse:581.43246	train-rmse:28.78406
# [3600]	validation-rmse:581.50359	train-rmse:28.23777
# [3650]	validation-rmse:581.51571	train-rmse:27.66956
# [3700]	validation-rmse:581.52653	train-rmse:27.02378
# [3750]	validation-rmse:581.61295	train-rmse:26.40702
# [3800]	validation-rmse:581.67940	train-rmse:25.78197
# [3850]	validation-rmse:581.73198	train-rmse:25.30170
# [3900]	validation-rmse:581.75129	train-rmse:24.87671
# [3950]	validation-rmse:581.79073	train-rmse:24.36426
# [4000]	validation-rmse:581.86083	train-rmse:23.90580
# [4050]	validation-rmse:581.86691	train-rmse:23.46151
# [4100]	validation-rmse:581.88057	train-rmse:22.97227
# [4150]	validation-rmse:581.82801	train-rmse:22.53431
# [4200]	validation-rmse:581.84928	train-rmse:22.05025
# [4250]	validation-rmse:581.89800	train-rmse:21.68452
# [4300]	validation-rmse:581.89809	train-rmse:21.36305
# [4350]	validation-rmse:581.92092	train-rmse:20.98194
# [4400]	validation-rmse:581.95278	train-rmse:20.59283
# [4450]	validation-rmse:582.00764	train-rmse:20.28865
# [4500]	validation-rmse:582.07031	train-rmse:19.97500
# [4550]	validation-rmse:582.03821	train-rmse:19.68310
# [4600]	validation-rmse:582.07163	train-rmse:19.41079
# [4650]	validation-rmse:582.10160	train-rmse:19.11245
# [4700]	validation-rmse:582.08099	train-rmse:18.79491
# [4750]	validation-rmse:582.09360	train-rmse:18.48141
# [4800]	validation-rmse:582.10937	train-rmse:18.14397
# [4850]	validation-rmse:582.13558	train-rmse:17.87896
# [4900]	validation-rmse:582.18721	train-rmse:17.60688
# [4950]	validation-rmse:582.21424	train-rmse:17.39102
# [5000]	validation-rmse:582.23123	train-rmse:17.15711
# [5050]	validation-rmse:582.23136	train-rmse:16.88938
# [5100]	validation-rmse:582.22244	train-rmse:16.65956
# [5150]	validation-rmse:582.25232	train-rmse:16.42653
# [5200]	validation-rmse:582.27981	train-rmse:16.21521
# [5250]	validation-rmse:582.29156	train-rmse:15.99624
# [5300]	validation-rmse:582.31081	train-rmse:15.82504
# [5350]	validation-rmse:582.32128	train-rmse:15.64142
# [5400]	validation-rmse:582.36411	train-rmse:15.41453
# [5450]	validation-rmse:582.38972	train-rmse:15.20075
# [5500]	validation-rmse:582.40910	train-rmse:15.00659
# [5550]	validation-rmse:582.42704	train-rmse:14.81193
# [5600]	validation-rmse:582.44487	train-rmse:14.63353
# [5650]	validation-rmse:582.43543	train-rmse:14.47880
# [5700]	validation-rmse:582.43586	train-rmse:14.30509
# [5750]	validation-rmse:582.44321	train-rmse:14.15176
# [5800]	validation-rmse:582.45988	train-rmse:13.99646
# [5850]	validation-rmse:582.45463	train-rmse:13.84621
# [5900]	validation-rmse:582.46866	train-rmse:13.72504
# [5950]	validation-rmse:582.49194	train-rmse:13.56224
# [6000]	validation-rmse:582.49056	train-rmse:13.42440
# [6050]	validation-rmse:582.50529	train-rmse:13.29912
# [6100]	validation-rmse:582.50828	train-rmse:13.17670
# [6150]	validation-rmse:582.52620	train-rmse:13.04655
# [6200]	validation-rmse:582.53411	train-rmse:12.93459
# [6250]	validation-rmse:582.55184	train-rmse:12.83556
# [6300]	validation-rmse:582.53963	train-rmse:12.73964
# [6350]	validation-rmse:582.55578	train-rmse:12.64112
# [6400]	validation-rmse:582.54415	train-rmse:12.52134
# [6450]	validation-rmse:582.54322	train-rmse:12.43101
# [6500]	validation-rmse:582.54236	train-rmse:12.33491
# [6550]	validation-rmse:582.53920	train-rmse:12.26093
# [6600]	validation-rmse:582.53031	train-rmse:12.17233
# [6650]	validation-rmse:582.55147	train-rmse:12.08524
# [6700]	validation-rmse:582.56922	train-rmse:12.01663
# [6750]	validation-rmse:582.55523	train-rmse:11.91651
# [6800]	validation-rmse:582.55392	train-rmse:11.84634
# [6850]	validation-rmse:582.56600	train-rmse:11.76100
# [6900]	validation-rmse:582.56648	train-rmse:11.67768
# [6950]	validation-rmse:582.56798	train-rmse:11.59478
# [7000]	validation-rmse:582.57662	train-rmse:11.51327
# [7050]	validation-rmse:582.58254	train-rmse:11.43400
# [7100]	validation-rmse:582.59656	train-rmse:11.37746
# [7150]	validation-rmse:582.60636	train-rmse:11.31166
# [7200]	validation-rmse:582.61194	train-rmse:11.24685
# [7250]	validation-rmse:582.62320	train-rmse:11.19055
# [7300]	validation-rmse:582.63225	train-rmse:11.13239
# [7350]	validation-rmse:582.64320	train-rmse:11.06283
# [7400]	validation-rmse:582.63580	train-rmse:11.01135
# [7450]	validation-rmse:582.64322	train-rmse:10.96606
# [7500]	validation-rmse:582.65106	train-rmse:10.90900
# [7550]	validation-rmse:582.65457	train-rmse:10.86503
# [7600]	validation-rmse:582.65576	train-rmse:10.81637
# [7650]	validation-rmse:582.67070	train-rmse:10.76753
# [7700]	validation-rmse:582.66700	train-rmse:10.72318
# [7750]	validation-rmse:582.66627	train-rmse:10.67841
# [7800]	validation-rmse:582.68057	train-rmse:10.62925
# [7850]	validation-rmse:582.68589	train-rmse:10.58707
# [7900]	validation-rmse:582.68525	train-rmse:10.55264
# [7950]	validation-rmse:582.68451	train-rmse:10.51172
# [8000]	validation-rmse:582.67820	train-rmse:10.47660
# [8050]	validation-rmse:582.68992	train-rmse:10.44340
# [8100]	validation-rmse:582.69293	train-rmse:10.40272
# [8150]	validation-rmse:582.70525	train-rmse:10.36043
# [8200]	validation-rmse:582.69817	train-rmse:10.33167
# [8250]	validation-rmse:582.70346	train-rmse:10.30108
# [8300]	validation-rmse:582.70439	train-rmse:10.27267
# [8350]	validation-rmse:582.70580	train-rmse:10.24643
# [8400]	validation-rmse:582.70940	train-rmse:10.22046
# [8450]	validation-rmse:582.71472	train-rmse:10.19604
# [8500]	validation-rmse:582.72539	train-rmse:10.16553
# [8550]	validation-rmse:582.73033	train-rmse:10.14041
# [8600]	validation-rmse:582.73054	train-rmse:10.11471
# [8650]	validation-rmse:582.72724	train-rmse:10.08588
# [8700]	validation-rmse:582.73057	train-rmse:10.06167
# [8750]	validation-rmse:582.73385	train-rmse:10.03847
# [8800]	validation-rmse:582.74955	train-rmse:10.01975
# [8850]	validation-rmse:582.75159	train-rmse:9.99892
# [8900]	validation-rmse:582.75529	train-rmse:9.98066
# [8950]	validation-rmse:582.75166	train-rmse:9.96343
# [9000]	validation-rmse:582.75673	train-rmse:9.94908
# [9050]	validation-rmse:582.75938	train-rmse:9.93224
# [9100]	validation-rmse:582.76327	train-rmse:9.91058
# [9150]	validation-rmse:582.77676	train-rmse:9.89564
# [9200]	validation-rmse:582.78294	train-rmse:9.88143
# [9250]	validation-rmse:582.78424	train-rmse:9.86601
# [9300]	validation-rmse:582.78187	train-rmse:9.85195
# [9350]	validation-rmse:582.78333	train-rmse:9.83798
# [9400]	validation-rmse:582.78332	train-rmse:9.81965
# [9450]	validation-rmse:582.79069	train-rmse:9.80636
# [9500]	validation-rmse:582.79386	train-rmse:9.79081
# [9550]	validation-rmse:582.79868	train-rmse:9.77634
# [9600]	validation-rmse:582.80245	train-rmse:9.76058
# [9650]	validation-rmse:582.80389	train-rmse:9.74661
# [9700]	validation-rmse:582.80438	train-rmse:9.73250
# [9750]	validation-rmse:582.80453	train-rmse:9.72182
# [9800]	validation-rmse:582.80528	train-rmse:9.70997
# [9850]	validation-rmse:582.80846	train-rmse:9.69988
# [9900]	validation-rmse:582.81247	train-rmse:9.69014
# [9950]	validation-rmse:582.81573	train-rmse:9.68036
# [9999]	validation-rmse:582.81551	train-rmse:9.67083

# %%
# XGBoost cross validation
params = {"objective": "reg:squarederror", "tree_method": "gpu_hist"}
n = 1000

results = xgb.cv(
   params, dtrain_reg,
   num_boost_round=n,
   nfold=5,
   early_stopping_rounds=20
)

# %%
results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0      2874.530912        9.576510     2877.437274      37.093540
# 1      2089.327469        8.317290     2094.021636      24.828795
# 2      1550.617973        5.223297     1558.386252      18.540267
# 3      1183.812759        5.193420     1195.032441      13.471580
# 4       941.203113        4.539805      958.728828       9.479449

# %%
best_rmse = results['test-rmse-mean'].min()

best_rmse
# Out:
# 549.311480649509

# %%
# XGBoost classification
from sklearn.preprocessing import OrdinalEncoder

X, y = diamonds.drop("cut", axis=1), diamonds[['cut']]

# Encode y to numeric
y_encoded = OrdinalEncoder().fit_transform(y)

# Extract text features
cats = X.select_dtypes(exclude=np.number).columns.tolist()

# Convert to pd.Categorical
for col in cats:
   X[col] = X[col].astype('category')

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, random_state=1, stratify=y_encoded)

# %%
# Create classification matrices
dtrain_clf = xgb.DMatrix(X_train, y_train, enable_categorical=True)
dtest_clf = xgb.DMatrix(X_test, y_test, enable_categorical=True)

# %%
params = {"objective": "multi:softprob", "tree_method": "gpu_hist", "num_class": 5}
n = 1000

results = xgb.cv(
   params, dtrain_clf,
   num_boost_round=n,
   nfold=5,
   metrics=["mlogloss", "auc", "merror"],
)

# %%
results.keys()
# Out:
# Index(['train-mlogloss-mean', 'train-mlogloss-std', 'train-auc-mean',
#        'train-auc-std', 'train-merror-mean', 'train-merror-std',
#        'test-mlogloss-mean', 'test-mlogloss-std', 'test-auc-mean',
#        'test-auc-std', 'test-merror-mean', 'test-merror-std'],
#       dtype='object')

# %%
# XGBoost Naive vs XGBoost Sklearn
import xgboost as xgb

# Train a model using the scikit-learn API
xgb_classifier = xgb.XGBClassifier(n_estimators=100, objective='binary:logistic', tree_method='hist', eta=0.1, max_depth=3, enable_categorical=True)
xgb_classifier.fit(X_train, y_train)

# Convert the model to a native API model
model = xgb_classifier.get_booster()
