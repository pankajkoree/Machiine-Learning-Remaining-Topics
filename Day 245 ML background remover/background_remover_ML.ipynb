# %% [markdown]
# # Background removing

# %%
from PIL import Image
from rembg import remove

# %%
inp_image = r'C:\Users\panka\Downloads\image-cropped-8x10.jpg'
out_img = 'output.jpg'

# %%
input = Image.open(inp_image)

# %%
output = remove(input)
# Out:
# Downloading data from 'https://github.com/danielgatis/rembg/releases/download/v0.0.0/u2net.onnx' to file 'C:\Users\panka\.u2net\u2net.onnx'.
# 100%|########################################| 176M/176M [00:00<00:00, 176GB/s]

# %%
output
# Out:
# <PIL.Image.Image image mode=RGBA size=406x503>
